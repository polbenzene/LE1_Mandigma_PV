# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set()

# %%
import pandas as pd
bike = pd.read_csv('/content/drive/MyDrive/ML/bike+sharing+dataset/day.csv')
bike.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
bike.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# std      0.465233    0.544894    0.183051    0.162961    0.142429    0.077498
# min      0.000000    1.000000    0.059130    0.079070    0.000000    0.022392
# 25%      0.000000    1.000000    0.337083    0.337842    0.520000    0.134950
# 50%      1.000000    1.000000    0.498333    0.486733    0.626667    0.180975
# 75%      1.000000    2.000000    0.655417    0.608602    0.730209    0.233214
# max      1.000000    3.000000    0.861667    0.840896    0.972500    0.507463
#
#             casual   registered          cnt
# count   731.000000   731.000000   731.000000
# mean    848.176471  3656.172367  4504.348837
# std     686.622488  1560.256377  1937.211452
# min       2.000000    20.000000    22.000000
# 25%     315.500000  2497.000000  3152.000000
# 50%     713.000000  3662.000000  4548.000000
# 75%    1096.000000  4776.500000  5956.000000
# max    3410.000000  6946.000000  8714.000000

# %%
print(bike.shape)
# Out:
# (731, 16)

# %%
round(100*(bike.isnull().sum()/len(bike)), 2).sort_values(ascending=False)
# Out:
# instant       0.0
# dteday        0.0
# season        0.0
# yr            0.0
# mnth          0.0
# holiday       0.0
# weekday       0.0
# workingday    0.0
# weathersit    0.0
# temp          0.0
# atemp         0.0
# hum           0.0
# windspeed     0.0
# casual        0.0
# registered    0.0
# cnt           0.0
# dtype: float64

# %%
round((bike.isnull().sum(axis=1)/len(bike))*100,2).sort_values(ascending=False)
# Out:
# 0      0.0
# 480    0.0
# 482    0.0
# 483    0.0
# 484    0.0
#       ...
# 245    0.0
# 246    0.0
# 247    0.0
# 248    0.0
# 730    0.0
# Length: 731, dtype: float64

# %%
bike_dup = bike.copy()

# Checking for duplicates and dropping the entire duplicate row if any
bike_dup.drop_duplicates(subset=None, inplace=True)

# %%
bike_dup.shape
# Out:
# (731, 16)

# %%
bike.shape
# Out:
# (731, 16)

# %%
import missingno as mn
mn.matrix(bike)

# %%
bike['dteday'].dtype
# Out:
# dtype('O')

# %%
bike['dteday'] =  pd.to_datetime(bike['dteday'],format='%Y-%m-%d')
bike['dteday'].dtype
# Out:
# dtype('<M8[ns]')

# %%
bike['year'] = pd.DatetimeIndex(bike['dteday']).year
bike['month'] = pd.DatetimeIndex(bike['dteday']).month

# %%
bike.head()
# Out:
#    instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1        0        6           0
# 1        2 2011-01-02       1   0     1        0        0           0
# 2        3 2011-01-03       1   0     1        0        1           1
# 3        4 2011-01-04       1   0     1        0        2           1
# 4        5 2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt  year  month
# 0   985  2011      1
# 1   801  2011      1
# 2  1349  2011      1
# 3  1562  2011      1
# 4  1600  2011      1

# %%
bike.drop(['yr','mnth'],axis=1,inplace=True)

# %%
bike.head()
# Out:
#    instant     dteday  season  holiday  weekday  workingday  weathersit  \
# 0        1 2011-01-01       1        0        6           0           2
# 1        2 2011-01-02       1        0        0           0           2
# 2        3 2011-01-03       1        0        1           1           1
# 3        4 2011-01-04       1        0        2           1           1
# 4        5 2011-01-05       1        0        3           1           1
#
#        temp     atemp       hum  windspeed  casual  registered   cnt  year  \
# 0  0.344167  0.363625  0.805833   0.160446     331         654   985  2011
# 1  0.363478  0.353739  0.696087   0.248539     131         670   801  2011
# 2  0.196364  0.189405  0.437273   0.248309     120        1229  1349  2011
# 3  0.200000  0.212122  0.590435   0.160296     108        1454  1562  2011
# 4  0.226957  0.229270  0.436957   0.186900      82        1518  1600  2011
#
#    month
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
bike.drop('holiday',axis=1,inplace=True)

# %%
bike.head()
# Out:
#    instant     dteday  season  weekday  workingday  weathersit      temp  \
# 0        1 2011-01-01       1        6           0           2  0.344167
# 1        2 2011-01-02       1        0           0           2  0.363478
# 2        3 2011-01-03       1        1           1           1  0.196364
# 3        4 2011-01-04       1        2           1           1  0.200000
# 4        5 2011-01-05       1        3           1           1  0.226957
#
#       atemp       hum  windspeed  casual  registered   cnt  year  month
# 0  0.363625  0.805833   0.160446     331         654   985  2011      1
# 1  0.353739  0.696087   0.248539     131         670   801  2011      1
# 2  0.189405  0.437273   0.248309     120        1229  1349  2011      1
# 3  0.212122  0.590435   0.160296     108        1454  1562  2011      1
# 4  0.229270  0.436957   0.186900      82        1518  1600  2011      1

# %%
bike.drop(['dteday','instant','casual','registered'],axis=1,inplace=True)

# %%
bike.head()
# Out:
#    season  weekday  workingday  weathersit      temp     atemp       hum  \
# 0       1        6           0           2  0.344167  0.363625  0.805833
# 1       1        0           0           2  0.363478  0.353739  0.696087
# 2       1        1           1           1  0.196364  0.189405  0.437273
# 3       1        2           1           1  0.200000  0.212122  0.590435
# 4       1        3           1           1  0.226957  0.229270  0.436957
#
#    windspeed   cnt  year  month
# 0   0.160446   985  2011      1
# 1   0.248539   801  2011      1
# 2   0.248309  1349  2011      1
# 3   0.160296  1562  2011      1
# 4   0.186900  1600  2011      1

# %%
bike.rename(columns={'hum':'humidity','cnt':'count'},inplace=True)

# %%
bike.head()
# Out:
#    season  weekday  workingday  weathersit      temp     atemp  humidity  \
# 0       1        6           0           2  0.344167  0.363625  0.805833
# 1       1        0           0           2  0.363478  0.353739  0.696087
# 2       1        1           1           1  0.196364  0.189405  0.437273
# 3       1        2           1           1  0.200000  0.212122  0.590435
# 4       1        3           1           1  0.226957  0.229270  0.436957
#
#    windspeed  count  year  month
# 0   0.160446    985  2011      1
# 1   0.248539    801  2011      1
# 2   0.248309   1349  2011      1
# 3   0.160296   1562  2011      1
# 4   0.186900   1600  2011      1

# %%
codes = {1:'spring',2:'summer',3:'fall',4:'winter'}
bike['season'] = bike['season'].map(codes)

# %%
sns.barplot('season', 'count', data = bike)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-3d7293bf4a27> in <cell line: 1>()
# ----> 1 sns.barplot('season', 'count', data = bike)
#
# TypeError: barplot() got multiple values for argument 'data'
